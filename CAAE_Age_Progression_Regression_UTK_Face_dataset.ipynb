# %%
# !git clone https://github.com/ajithvallabai/CAAE-Age_Progression_Regression_Pytorch
# Out:
# Cloning into 'CAAE-Age_Progression_Regression_Pytorch'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 20 (delta 0), reused 7 (delta 0), pack-reused 11
# Unpacking objects: 100% (20/20), done.

# %%
cd CAAE-Age_Progression_Regression_Pytorch/
# Out:
# /content/CAAE-Age_Progression_Regression_Pytorch

# %%
# UTK Face datset - 23k images
#https://drive.google.com/file/d/0BxYys69jI14kYVM3aVhKS1VhRUk/view?usp=sharing

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0BxYys69jI14kYVM3aVhKS1VhRUk' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0BxYys69jI14kYVM3aVhKS1VhRUk" -O utk.tar.gz && rm -rf /tmp/cookies.txt
# Out:
# --2021-01-31 18:21:55--  https://docs.google.com/uc?export=download&confirm=1TSE&id=0BxYys69jI14kYVM3aVhKS1VhRUk
# Resolving docs.google.com (docs.google.com)... 142.250.73.206, 2607:f8b0:4004:808::200e
# Connecting to docs.google.com (docs.google.com)|142.250.73.206|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-1g-docs.googleusercontent.com/docs/securesc/0gob4b2ltai1eqa0vtia79gar378rh2t/73v43dp46j8f10cvl550poosu6ets8j5/1612117275000/16869955760404710258/00860704437723411893Z/0BxYys69jI14kYVM3aVhKS1VhRUk?e=download [following]
# --2021-01-31 18:21:56--  https://doc-14-1g-docs.googleusercontent.com/docs/securesc/0gob4b2ltai1eqa0vtia79gar378rh2t/73v43dp46j8f10cvl550poosu6ets8j5/1612117275000/16869955760404710258/00860704437723411893Z/0BxYys69jI14kYVM3aVhKS1VhRUk?e=download
# Resolving doc-14-1g-docs.googleusercontent.com (doc-14-1g-docs.googleusercontent.com)... 172.217.164.129, 2607:f8b0:4004:814::2001
# ...

# %%
# !ls
# Out:
# CAAE_128_jupyter.ipynb	main.py       misc.py	 README.md
# dataloader.py		makeLabel.py  models.py  utk.zip

# %%
# !tar -xvzf utk.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# UTKFace/33_1_0_20170111182452825.jpg.chip.jpg
# UTKFace/26_1_1_20170116024053194.jpg.chip.jpg
# UTKFace/25_1_0_20170109213232182.jpg.chip.jpg
# UTKFace/28_1_1_20170112234526480.jpg.chip.jpg
# UTKFace/57_0_0_20170117191704100.jpg.chip.jpg
# UTKFace/27_1_1_20170117193211345.jpg.chip.jpg
# UTKFace/46_1_1_20170116161237892.jpg.chip.jpg
# UTKFace/24_0_2_20170116171647508.jpg.chip.jpg
# UTKFace/42_1_1_20170113005712902.jpg.chip.jpg
# UTKFace/25_1_1_20170116001337504.jpg.chip.jpg
# UTKFace/40_1_0_20170116222110661.jpg.chip.jpg
# UTKFace/50_1_0_20170109012257664.jpg.chip.jpg
# UTKFace/26_1_3_20170104235421282.jpg.chip.jpg
# UTKFace/7_0_0_20170110215711115.jpg.chip.jpg
# UTKFace/1_1_2_20161219155353413.jpg.chip.jpg
# UTKFace/26_0_1_20170117195651493.jpg.chip.jpg
# UTKFace/7_0_0_20170110215648859.jpg.chip.jpg
# UTKFace/64_0_0_20170117155540137.jpg.chip.jpg
# UTKFace/48_0_0_20170109004813150.jpg.chip.jpg
# ...

# %%
# !pip install torchvision==0.4.0
# Out:
# ...
#      |████████████████████████████████| 8.8MB 11.4MB/s
# ...
#      |████████████████████████████████| 748.9MB 13kB/s
# ...
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# ...

# %%
# !pip install pillow==6
# Out:
# ...
#      |████████████████████████████████| 2.0MB 18.8MB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# ...

# %%
# !ls
# Out:
# assests						models.py
# CAAE_128_jupyter.ipynb				noteofthisrepo
# dataloader.py					README.md
# Face_Aging_CAAE_Pytorch_UTK_Face_dataset.ipynb	requirements.txt
# main.py						UTKFace
# makeLabel.py					utk.tar.gz
# misc.py

# %%
cd CAAE-Age_Progression_Regression_Pytorch/
# Out:
# [Errno 2] No such file or directory: 'CAAE-Age_Progression_Regression_Pytorch/'
# /content/CAAE-Age_Progression_Regression_Pytorch

# %% [markdown]
# ## Use in case if you want to reduce the number of images in a director

# %%
cd UTKFace/
# Out:
# /content/CAAE-Age_Progression_Regression_Pytorch/UTKFace

# %%
# Measuring number of images in UTKFace dir
# !ls -1 | wc -l
# Out:
# 1709

# %%
# removing 20000 images from UTKFace directory
# !ls -U | head -22000 | xargs rm -rf

# %%
cd ..
# Out:
# /content/CAAE-Age_Progression_Regression_Pytorch

# %%
# remove if data directory is created already
# !rm -r data

# %% [markdown]
# ### Main program

# %%
# !python main.py
# Out:
# Epochs 0
# Data loaders -  0
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Data loaders -  1
# Data loaders -  2
# Data loaders -  3
# Data loaders -  4
# Data loaders -  5
# Data loaders -  6
# Data loaders -  7
# Data loaders -  8
# Data loaders -  9
# Data loaders -  10
# Data loaders -  11
# Data loaders -  12
# Data loaders -  13
# Data loaders -  14
# Data loaders -  15
# Data loaders -  16
# Data loaders -  17
# Data loaders -  18
# Data loaders -  19
# Data loaders -  20
# Data loaders -  21
# Data loaders -  22
# Data loaders -  23
# Data loaders -  24
# Data loaders -  25
# Data loaders -  26
# Data loaders -  27
# Data loaders -  28
# Data loaders -  29
# Data loaders -  30
# Data loaders -  31
# Data loaders -  32
# Data loaders -  33
# Data loaders -  34
# Data loaders -  35
# Data loaders -  36
# ...

# %%
# !ls
# Out:
# CAAE_128_jupyter.ipynb	infer.py      models.py		UTKFace
# data			main.py       __pycache__	utk.tar.gz
# dataloader.py		makeLabel.py  README.md
# fixed_noise.p		misc.py       result_tv_gender

# %%
# !zip -r output_file.zip result_tv_gender
# Out:
#   adding: result_tv_gender/ (stored 0%)
#   adding: result_tv_gender/netD_img_021.pth (deflated 7%)
#   adding: result_tv_gender/netD_img_041.pth (deflated 7%)
#   adding: result_tv_gender/reconst_epoch018.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch013.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch003.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch042.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch034.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch024.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch043.png (deflated 0%)
#   adding: result_tv_gender/netD_z_011.pth (deflated 9%)
#   adding: result_tv_gender/reconst_epoch023.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch002.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch007.png (deflated 0%)
#   adding: result_tv_gender/reconst_epoch032.png (deflated 0%)
#   adding: result_tv_gender/netD_z_031.pth (deflated 9%)
# ...

# %%
# !ls -sh results.zip
# Out:
# 202M results.zip

# %%
# !mkdir results

# %%
# !cp result_tv_gender/netD_img_041.pth results/
# !cp result_tv_gender/netD_z_041.pth results/
# !cp result_tv_gender/netE_041.pth results/
# !cp result_tv_gender/netG_041.pth results/

# %%
# !zip -r results.zip results
# Out:
#   adding: results/ (stored 0%)
#   adding: results/netD_img_041.pth (deflated 7%)
#   adding: results/netE_041.pth (deflated 7%)
#   adding: results/netD_z_041.pth (deflated 9%)
#   adding: results/netG_041.pth (deflated 7%)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mkdir '/content/gdrive/My Drive/AgeGAN'

# %%
# !cp results.zip '/content/gdrive/My Drive/AgeGAN/'

# %%
# !zip
